# %%
def func(): pass
class A: pass
lambda x: x+1
# Out:
# <function __main__.<lambda>(x)>

# %%
def doeg(a:str=None):
    print('diego')

# %%
a = lambda x: x+1

# %%
callable(lambda x: x+1)
# Out:
# True

# %%
callable(doeg)
# Out:
# True
